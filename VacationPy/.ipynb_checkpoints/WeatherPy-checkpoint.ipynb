# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Today
today = time.strftime("%m/%d/%y")

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Openweathermap API call: api.openweathermap.org/data/2.5/weather?q={city name}&appid={your api key}
base_url = "https://api.openweathermap.org/data/2.5/weather?q="

# DataFrame for Cities
weather_df = pd.DataFrame({"City":cities})

# Record and set count
Record = 0
Set = 1

# Placeholders for Latitude, Longitude, Temperature(F), Humidity (%), Cloudiness (%), Wind Speed (mph), Country, and DateTime
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Temperature (F)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Wind Speed (mph)"] = ""
weather_df["Country"] = ""
weather_df["DateTime"] = ""

# Printing for aestethics
print("Beginning Data Retrieval")
print("----------------------------")

# Initializing and completing requests
for index, city in enumerate(cities):
    
    print(f'Processing Record {Record} of set {Set} | {city}')
    
    try:
        
        requests_url = f'{base_url}{city}&appid={weather_api_key}'
        response = requests.get(requests_url).json()
    
        weather_df.loc[index, "Latitude"] = response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = response["coord"]["lon"]
        weather_df.loc[index, "Temperature (F)"] = 1.8 * (response["main"]["temp"] - 273) + 32
        weather_df.loc[index, "Humidity (%)"] = response["main"]["humidity"]
        weather_df.loc[index, "Cloudiness (%)"] = response["clouds"]["all"]
        weather_df.loc[index, "Wind Speed (mph)"] = response["wind"]["speed"]
        weather_df.loc[index, "Country"] = response['sys']["country"]
        weather_df.loc[index, "DateTime"] = datetime.datetime.fromtimestamp(response["dt"])
    
    except:
        print(f"City not found. Skipping | {city}")
        
    Record += 1
    
    if Record > 50:
        Set += 1
        Record = 0

print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 0 of set 1 | barrow
# Processing Record 1 of set 1 | hilo
# Processing Record 2 of set 1 | ushuaia
# Processing Record 3 of set 1 | teya
# Processing Record 4 of set 1 | rikitea
# Processing Record 5 of set 1 | hobart
# Processing Record 6 of set 1 | pevek
# Processing Record 7 of set 1 | albany
# Processing Record 8 of set 1 | busselton
# Processing Record 9 of set 1 | hermanus
# Processing Record 10 of set 1 | saint-philippe
# Processing Record 11 of set 1 | mataura
# Processing Record 12 of set 1 | sorland
# Processing Record 13 of set 1 | bluff
# Processing Record 14 of set 1 | nikolskoye
# Processing Record 15 of set 1 | rind
# Processing Record 16 of set 1 | new norfolk
# Processing Record 17 of set 1 | sorvag
# City not found. Skipping | sorvag
# Processing Record 18 of set 1 | hastings
# Processing Record 19 of set 1 | puerto ayora
# Processing Record 20 of set 1 | kahului
# Processing Record 21 of set 1 | cherskiy
# Processing Record 22 of set 1 | atuona
# Processing Record 23 of set 1 | cape town
# Processing Record 24 of set 1 | yining
# Processing Record 25 of set 1 | amderma
# City not found. Skipping | amderma
# Processing Record 26 of set 1 | port alfred
# Processing Record 27 of set 1 | port elizabeth
# Processing Record 28 of set 1 | yulara
# Processing Record 29 of set 1 | shiraz
# Processing Record 30 of set 1 | bambous virieux
# Processing Record 31 of set 1 | kodiak
# Processing Record 32 of set 1 | hithadhoo
# Processing Record 33 of set 1 | bonavista
# Processing Record 34 of set 1 | russell
# Processing Record 35 of set 1 | taolanaro
# City not found. Skipping | taolanaro
# Processing Record 36 of set 1 | mys shmidta
# City not found. Skipping | mys shmidta
# Processing Record 37 of set 1 | punta arenas
# Processing Record 38 of set 1 | rio gallegos
# Processing Record 39 of set 1 | butaritari
# Processing Record 40 of set 1 | kaitangata
# Processing Record 41 of set 1 | lavrentiya
# Processing Record 42 of set 1 | vrangel
# Processing Record 43 of set 1 | saskylakh
# Processing Record 44 of set 1 | fortuna
# Processing Record 45 of set 1 | vaini
# Processing Record 46 of set 1 | bengkulu
# Processing Record 47 of set 1 | qaanaaq
# Processing Record 48 of set 1 | torbay
# Processing Record 49 of set 1 | sura
# Processing Record 50 of set 1 | bethel
# Processing Record 0 of set 2 | baruun-urt
# Processing Record 1 of set 2 | inhambane
# Processing Record 2 of set 2 | san patricio
# Processing Record 3 of set 2 | bredasdorp
# Processing Record 4 of set 2 | diego de almagro
# Processing Record 5 of set 2 | srednekolymsk
# Processing Record 6 of set 2 | dicabisagan
# Processing Record 7 of set 2 | vao
# Processing Record 8 of set 2 | okhotsk
# Processing Record 9 of set 2 | jamestown
# Processing Record 10 of set 2 | dikson
# Processing Record 11 of set 2 | old saybrook
# Processing Record 12 of set 2 | sorong
# Processing Record 13 of set 2 | arraial do cabo
# Processing Record 14 of set 2 | kurdzhinovo
# Processing Record 15 of set 2 | east london
# Processing Record 16 of set 2 | lorengau
# Processing Record 17 of set 2 | pechora
# Processing Record 18 of set 2 | beyneu
# Processing Record 19 of set 2 | tura
# Processing Record 20 of set 2 | lebu
# Processing Record 21 of set 2 | cesvaine
# Processing Record 22 of set 2 | marienburg
# Processing Record 23 of set 2 | nizhneyansk
# City not found. Skipping | nizhneyansk
# Processing Record 24 of set 2 | yuma
# Processing Record 25 of set 2 | georgetown
# Processing Record 26 of set 2 | carnarvon
# Processing Record 27 of set 2 | grand river south east
# City not found. Skipping | grand river south east
# Processing Record 28 of set 2 | saint george
# Processing Record 29 of set 2 | iacu
# Processing Record 30 of set 2 | kapaa
# Processing Record 31 of set 2 | sunrise manor
# Processing Record 32 of set 2 | klyuchi
# Processing Record 33 of set 2 | olafsvik
# Processing Record 34 of set 2 | mount gambier
# Processing Record 35 of set 2 | bucyrus
# Processing Record 36 of set 2 | coahuayana
# Processing Record 37 of set 2 | katsuura
# Processing Record 38 of set 2 | chokurdakh
# Processing Record 39 of set 2 | port lincoln
# Processing Record 40 of set 2 | halifax
# Processing Record 41 of set 2 | salinopolis
# Processing Record 42 of set 2 | marcona
# City not found. Skipping | marcona
# Processing Record 43 of set 2 | naze
# Processing Record 44 of set 2 | krasnoturansk
# Processing Record 45 of set 2 | saint-francois
# Processing Record 46 of set 2 | lagoa
# Processing Record 47 of set 2 | mwinilunga
# Processing Record 48 of set 2 | kenai
# Processing Record 49 of set 2 | khorramshahr
# Processing Record 50 of set 2 | avarua
# Processing Record 0 of set 3 | richards bay
# Processing Record 1 of set 3 | vostok
# Processing Record 2 of set 3 | mahebourg
# Processing Record 3 of set 3 | beni suef
# Processing Record 4 of set 3 | severo-kurilsk
# Processing Record 5 of set 3 | nouadhibou
# Processing Record 6 of set 3 | touros
# Processing Record 7 of set 3 | ribeira grande
# Processing Record 8 of set 3 | hasaki
# Processing Record 9 of set 3 | gillette
# Processing Record 10 of set 3 | ambodifototra
# City not found. Skipping | ambodifototra
# Processing Record 11 of set 3 | chuy
# Processing Record 12 of set 3 | belushya guba
# City not found. Skipping | belushya guba
# Processing Record 13 of set 3 | lethem
# Processing Record 14 of set 3 | salalah
# Processing Record 15 of set 3 | longyearbyen
# Processing Record 16 of set 3 | yenagoa
# Processing Record 17 of set 3 | cockburn town
# Processing Record 18 of set 3 | mar del plata
# Processing Record 19 of set 3 | khatanga
# Processing Record 20 of set 3 | bilibino
# Processing Record 21 of set 3 | dongsheng
# Processing Record 22 of set 3 | valparaiso
# Processing Record 23 of set 3 | kokopo
# Processing Record 24 of set 3 | yellowknife
# Processing Record 25 of set 3 | aden
# Processing Record 26 of set 3 | payson
# Processing Record 27 of set 3 | grindavik
# Processing Record 28 of set 3 | la ronge
# Processing Record 29 of set 3 | manjacaze
# Processing Record 30 of set 3 | colares
# Processing Record 31 of set 3 | brae
# Processing Record 32 of set 3 | victoria
# Processing Record 33 of set 3 | chateauroux
# Processing Record 34 of set 3 | dombarovskiy
# Processing Record 35 of set 3 | tautira
# Processing Record 36 of set 3 | bubaque
# Processing Record 37 of set 3 | kavaratti
# Processing Record 38 of set 3 | asau
# Processing Record 39 of set 3 | port blair
# Processing Record 40 of set 3 | saint-georges
# Processing Record 41 of set 3 | talnakh
# Processing Record 42 of set 3 | sisimiut
# Processing Record 43 of set 3 | norman wells
# Processing Record 44 of set 3 | henties bay
# Processing Record 45 of set 3 | tuktoyaktuk
# Processing Record 46 of set 3 | dunedin
# Processing Record 47 of set 3 | kaeo
# Processing Record 48 of set 3 | namibe
# Processing Record 49 of set 3 | houma
# Processing Record 50 of set 3 | mogok
# Processing Record 0 of set 4 | tasiilaq
# Processing Record 1 of set 4 | gilbues
# Processing Record 2 of set 4 | fort nelson
# Processing Record 3 of set 4 | thompson
# Processing Record 4 of set 4 | pimentel
# Processing Record 5 of set 4 | beloha
# Processing Record 6 of set 4 | hualmay
# Processing Record 7 of set 4 | tortoli
# Processing Record 8 of set 4 | mount isa
# Processing Record 9 of set 4 | okato
# Processing Record 10 of set 4 | santiago
# Processing Record 11 of set 4 | zambezi
# Processing Record 12 of set 4 | tiarei
# Processing Record 13 of set 4 | illoqqortoormiut
# City not found. Skipping | illoqqortoormiut
# Processing Record 14 of set 4 | thinadhoo
# Processing Record 15 of set 4 | juybar
# Processing Record 16 of set 4 | takoradi
# Processing Record 17 of set 4 | clyde river
# Processing Record 18 of set 4 | clyde
# Processing Record 19 of set 4 | saldanha
# Processing Record 20 of set 4 | mahon
# Processing Record 21 of set 4 | batticaloa
# Processing Record 22 of set 4 | chimaltenango
# Processing Record 23 of set 4 | vaitupu
# City not found. Skipping | vaitupu
# Processing Record 24 of set 4 | amapa
# Processing Record 25 of set 4 | tocopilla
# Processing Record 26 of set 4 | laguna
# Processing Record 27 of set 4 | sinegorye
# Processing Record 28 of set 4 | shakiso
# Processing Record 29 of set 4 | antalya
# Processing Record 30 of set 4 | abu dhabi
# Processing Record 31 of set 4 | tapaua
# City not found. Skipping | tapaua
# Processing Record 32 of set 4 | tucumcari
# Processing Record 33 of set 4 | agropoli
# Processing Record 34 of set 4 | balaguer
# Processing Record 35 of set 4 | bukama
# Processing Record 36 of set 4 | broken hill
# Processing Record 37 of set 4 | northam
# Processing Record 38 of set 4 | kharabali
# Processing Record 39 of set 4 | ormara
# Processing Record 40 of set 4 | pavullo nel frignano
# Processing Record 41 of set 4 | tilichiki
# Processing Record 42 of set 4 | gwadar
# Processing Record 43 of set 4 | erzin
# Processing Record 44 of set 4 | codrington
# Processing Record 45 of set 4 | luanda
# Processing Record 46 of set 4 | cabo san lucas
# Processing Record 47 of set 4 | vega de alatorre
# Processing Record 48 of set 4 | millville
# Processing Record 49 of set 4 | kieta
# Processing Record 50 of set 4 | praya
# Processing Record 0 of set 5 | castro
# Processing Record 1 of set 5 | alofi
# Processing Record 2 of set 5 | lolua
# City not found. Skipping | lolua
# Processing Record 3 of set 5 | lanzhou
# Processing Record 4 of set 5 | pangnirtung
# Processing Record 5 of set 5 | guerrero negro
# Processing Record 6 of set 5 | shirokiy
# Processing Record 7 of set 5 | khandyga
# Processing Record 8 of set 5 | pakenham
# Processing Record 9 of set 5 | isangel
# Processing Record 10 of set 5 | klaksvik
# Processing Record 11 of set 5 | baturaja
# Processing Record 12 of set 5 | huai thalaeng
# Processing Record 13 of set 5 | cayenne
# Processing Record 14 of set 5 | luderitz
# Processing Record 15 of set 5 | kavieng
# Processing Record 16 of set 5 | ponta do sol
# Processing Record 17 of set 5 | sirjan
# Processing Record 18 of set 5 | balkanabat
# Processing Record 19 of set 5 | galveston
# Processing Record 20 of set 5 | along
# Processing Record 21 of set 5 | ha tinh
# Processing Record 22 of set 5 | east wenatchee bench
# Processing Record 23 of set 5 | lazaro cardenas
# Processing Record 24 of set 5 | warqla
# City not found. Skipping | warqla
# Processing Record 25 of set 5 | cairns
# Processing Record 26 of set 5 | hopelchen
# Processing Record 27 of set 5 | xianshuigu
# Processing Record 28 of set 5 | omboue
# Processing Record 29 of set 5 | iqaluit
# Processing Record 30 of set 5 | sarkand
# Processing Record 31 of set 5 | barentsburg
# City not found. Skipping | barentsburg
# Processing Record 32 of set 5 | imuris
# Processing Record 33 of set 5 | yarada
# Processing Record 34 of set 5 | bonthe
# Processing Record 35 of set 5 | maniitsoq
# Processing Record 36 of set 5 | san miguel
# Processing Record 37 of set 5 | san cristobal
# Processing Record 38 of set 5 | luwuk
# Processing Record 39 of set 5 | shizukuishi
# Processing Record 40 of set 5 | camana
# Processing Record 41 of set 5 | arkhangelos
# City not found. Skipping | arkhangelos
# Processing Record 42 of set 5 | mineros
# Processing Record 43 of set 5 | biloela
# Processing Record 44 of set 5 | dusti
# Processing Record 45 of set 5 | provideniya
# Processing Record 46 of set 5 | haines junction
# Processing Record 47 of set 5 | dudinka
# Processing Record 48 of set 5 | volkhov
# Processing Record 49 of set 5 | sao joao da barra
# Processing Record 50 of set 5 | kindu
# Processing Record 0 of set 6 | mrirt
# City not found. Skipping | mrirt
# Processing Record 1 of set 6 | sili
# Processing Record 2 of set 6 | algiers
# Processing Record 3 of set 6 | poya
# Processing Record 4 of set 6 | tomatlan
# Processing Record 5 of set 6 | mpika
# Processing Record 6 of set 6 | yate
# Processing Record 7 of set 6 | vangaindrano
# Processing Record 8 of set 6 | zhigansk
# Processing Record 9 of set 6 | pavlodar
# Processing Record 10 of set 6 | marzuq
# Processing Record 11 of set 6 | chernyshevskiy
# Processing Record 12 of set 6 | tshikapa
# Processing Record 13 of set 6 | atbasar
# Processing Record 14 of set 6 | husavik
# Processing Record 15 of set 6 | ghanzi
# Processing Record 16 of set 6 | lompoc
# Processing Record 17 of set 6 | uarini
# Processing Record 18 of set 6 | palabuhanratu
# City not found. Skipping | palabuhanratu
# Processing Record 19 of set 6 | neiafu
# Processing Record 20 of set 6 | finschhafen
# Processing Record 21 of set 6 | guara
# Processing Record 22 of set 6 | angoche
# Processing Record 23 of set 6 | kuche
# City not found. Skipping | kuche
# Processing Record 24 of set 6 | bajil
# Processing Record 25 of set 6 | herat
# Processing Record 26 of set 6 | preobrazheniye
# Processing Record 27 of set 6 | iracoubo
# Processing Record 28 of set 6 | dzhebariki-khaya
# Processing Record 29 of set 6 | la orilla
# Processing Record 30 of set 6 | tiksi
# Processing Record 31 of set 6 | mao
# Processing Record 32 of set 6 | natchez
# Processing Record 33 of set 6 | maykain
# City not found. Skipping | maykain
# Processing Record 34 of set 6 | gat
# Processing Record 35 of set 6 | bartica
# Processing Record 36 of set 6 | mixtepec
# City not found. Skipping | mixtepec
# Processing Record 37 of set 6 | airai
# Processing Record 38 of set 6 | poli
# Processing Record 39 of set 6 | kozhva
# Processing Record 40 of set 6 | sabang
# Processing Record 41 of set 6 | itarema
# Processing Record 42 of set 6 | camabatela
# Processing Record 43 of set 6 | manzhouli
# Processing Record 44 of set 6 | gizo
# Processing Record 45 of set 6 | xining
# Processing Record 46 of set 6 | portland
# Processing Record 47 of set 6 | villazon
# Processing Record 48 of set 6 | hihifo
# City not found. Skipping | hihifo
# Processing Record 49 of set 6 | caruray
# Processing Record 50 of set 6 | pangai
# Processing Record 0 of set 7 | ewa beach
# Processing Record 1 of set 7 | marsh harbour
# Processing Record 2 of set 7 | whitehorse
# Processing Record 3 of set 7 | marathon
# Processing Record 4 of set 7 | esperance
# Processing Record 5 of set 7 | ahipara
# Processing Record 6 of set 7 | goure
# Processing Record 7 of set 7 | mariana
# Processing Record 8 of set 7 | upernavik
# Processing Record 9 of set 7 | hammerfest
# Processing Record 10 of set 7 | beringovskiy
# Processing Record 11 of set 7 | huescar
# Processing Record 12 of set 7 | prince rupert
# Processing Record 13 of set 7 | hofn
# Processing Record 14 of set 7 | puerto escondido
# Processing Record 15 of set 7 | diu
# Processing Record 16 of set 7 | luangwa
# Processing Record 17 of set 7 | valkeala
# Processing Record 18 of set 7 | bandundu
# Processing Record 19 of set 7 | half moon bay
# Processing Record 20 of set 7 | kamenskoye
# City not found. Skipping | kamenskoye
# Processing Record 21 of set 7 | ojinaga
# Processing Record 22 of set 7 | samusu
# City not found. Skipping | samusu
# Processing Record 23 of set 7 | aberdeen
# Processing Record 24 of set 7 | nabire
# Processing Record 25 of set 7 | eureka
# Processing Record 26 of set 7 | skage
# City not found. Skipping | skage
# Processing Record 27 of set 7 | vestmanna
# Processing Record 28 of set 7 | azimur
# City not found. Skipping | azimur
# Processing Record 29 of set 7 | ribeira brava
# Processing Record 30 of set 7 | srivardhan
# Processing Record 31 of set 7 | lafia
# Processing Record 32 of set 7 | aksu
# Processing Record 33 of set 7 | nuevitas
# Processing Record 34 of set 7 | vila velha
# Processing Record 35 of set 7 | chilca
# Processing Record 36 of set 7 | chapais
# Processing Record 37 of set 7 | guanare
# Processing Record 38 of set 7 | pisco
# Processing Record 39 of set 7 | constitucion
# Processing Record 40 of set 7 | anadyr
# Processing Record 41 of set 7 | chicama
# Processing Record 42 of set 7 | mont-de-marsan
# Processing Record 43 of set 7 | nikki
# Processing Record 44 of set 7 | clarksburg
# Processing Record 45 of set 7 | parabel
# Processing Record 46 of set 7 | sentyabrskiy
# City not found. Skipping | sentyabrskiy
# Processing Record 47 of set 7 | warmbad
# Processing Record 48 of set 7 | kwekwe
# Processing Record 49 of set 7 | toledo
# Processing Record 50 of set 7 | faya
# Processing Record 0 of set 8 | muli
# Processing Record 1 of set 8 | floro
# Processing Record 2 of set 8 | susaki
# Processing Record 3 of set 8 | kidal
# Processing Record 4 of set 8 | sola
# Processing Record 5 of set 8 | kamaishi
# Processing Record 6 of set 8 | mankera
# Processing Record 7 of set 8 | korla
# Processing Record 8 of set 8 | bowen
# Processing Record 9 of set 8 | hit
# Processing Record 10 of set 8 | komsomolets
# Processing Record 11 of set 8 | pangoa
# Processing Record 12 of set 8 | grand gaube
# Processing Record 13 of set 8 | tsihombe
# City not found. Skipping | tsihombe
# Processing Record 14 of set 8 | puerto maldonado
# Processing Record 15 of set 8 | coquimbo
# Processing Record 16 of set 8 | nanortalik
# Processing Record 17 of set 8 | kununurra
# Processing Record 18 of set 8 | meulaboh
# Processing Record 19 of set 8 | ostrovnoy
# Processing Record 20 of set 8 | dehui
# Processing Record 21 of set 8 | atambua
# Processing Record 22 of set 8 | college
# Processing Record 23 of set 8 | puerto penasco
# Processing Record 24 of set 8 | kingaroy
# Processing Record 25 of set 8 | ilulissat
# Processing Record 26 of set 8 | kochevo
# Processing Record 27 of set 8 | salta
# Processing Record 28 of set 8 | san policarpo
# Processing Record 29 of set 8 | mezhdurechensk
# Processing Record 30 of set 8 | kiunga
# Processing Record 31 of set 8 | luganville
# Processing Record 32 of set 8 | vila franca do campo
# Processing Record 33 of set 8 | lucea
# Processing Record 34 of set 8 | misratah
# Processing Record 35 of set 8 | krasnoselkup
# Processing Record 36 of set 8 | norwich
# Processing Record 37 of set 8 | sandwick
# Processing Record 38 of set 8 | anloga
# Processing Record 39 of set 8 | necochea
# Processing Record 40 of set 8 | cabedelo
# Processing Record 41 of set 8 | barrhead
# Processing Record 42 of set 8 | khonuu
# City not found. Skipping | khonuu
# Processing Record 43 of set 8 | nalut
# Processing Record 44 of set 8 | vagur
# Processing Record 45 of set 8 | mazatlan
# Processing Record 46 of set 8 | tessalit
# Processing Record 47 of set 8 | mendoza
# Processing Record 48 of set 8 | goderich
# Processing Record 49 of set 8 | shingu
# Processing Record 50 of set 8 | haimen
# Processing Record 0 of set 9 | sobolevo
# Processing Record 1 of set 9 | formosa
# Processing Record 2 of set 9 | abeche
# Processing Record 3 of set 9 | tigzirt
# Processing Record 4 of set 9 | oksfjord
# Processing Record 5 of set 9 | faanui
# Processing Record 6 of set 9 | bourail
# Processing Record 7 of set 9 | hamilton
# Processing Record 8 of set 9 | kulhudhuffushi
# Processing Record 9 of set 9 | teahupoo
# Processing Record 10 of set 9 | cap malheureux
# Processing Record 11 of set 9 | carmen
# Processing Record 12 of set 9 | tevaitoa
# Processing Record 13 of set 9 | isiolo
# Processing Record 14 of set 9 | margate
# Processing Record 15 of set 9 | sur
# Processing Record 16 of set 9 | lokosovo
# Processing Record 17 of set 9 | fallon
# Processing Record 18 of set 9 | sicamous
# Processing Record 19 of set 9 | morondava
# Processing Record 20 of set 9 | roald
# Processing Record 21 of set 9 | attawapiskat
# City not found. Skipping | attawapiskat
# Processing Record 22 of set 9 | manzil tamim
# City not found. Skipping | manzil tamim
# Processing Record 23 of set 9 | ejea de los caballeros
# Processing Record 24 of set 9 | harper
# Processing Record 25 of set 9 | flinders
# Processing Record 26 of set 9 | shchelyayur
# City not found. Skipping | shchelyayur
# Processing Record 27 of set 9 | mayo
# Processing Record 28 of set 9 | punta alta
# Processing Record 29 of set 9 | la ligua
# Processing Record 30 of set 9 | vanimo
# Processing Record 31 of set 9 | samarai
# Processing Record 32 of set 9 | sao filipe
# Processing Record 33 of set 9 | suoyarvi
# Processing Record 34 of set 9 | oranjemund
# Processing Record 35 of set 9 | buin
# Processing Record 36 of set 9 | pringsewu
# Processing Record 37 of set 9 | pingliang
# Processing Record 38 of set 9 | kuusamo
# Processing Record 39 of set 9 | cerro azul
# Processing Record 40 of set 9 | belaya gora
# Processing Record 41 of set 9 | panguipulli
# Processing Record 42 of set 9 | tutoia
# Processing Record 43 of set 9 | minab
# Processing Record 44 of set 9 | concarneau
# Processing Record 45 of set 9 | klooga
# Processing Record 46 of set 9 | hambantota
# Processing Record 47 of set 9 | abu zabad
# Processing Record 48 of set 9 | poplar bluff
# Processing Record 49 of set 9 | picota
# Processing Record 50 of set 9 | flin flon
# Processing Record 0 of set 10 | saint anthony
# Processing Record 1 of set 10 | kitui
# Processing Record 2 of set 10 | jonesboro
# Processing Record 3 of set 10 | san juan
# Processing Record 4 of set 10 | sawtell
# Processing Record 5 of set 10 | tuatapere
# Processing Record 6 of set 10 | souillac
# Processing Record 7 of set 10 | los llanos de aridane
# Processing Record 8 of set 10 | ugoofaaru
# Processing Record 9 of set 10 | amnat charoen
# Processing Record 10 of set 10 | kemijarvi
# Processing Record 11 of set 10 | ewo
# Processing Record 12 of set 10 | north bend
# Processing Record 13 of set 10 | doka
# Processing Record 14 of set 10 | fowa
# Processing Record 15 of set 10 | aljezur
# Processing Record 16 of set 10 | alihe
# Processing Record 17 of set 10 | paka
# Processing Record 18 of set 10 | bathsheba
# Processing Record 19 of set 10 | moussoro
# Processing Record 20 of set 10 | scottsburgh
# City not found. Skipping | scottsburgh
# Processing Record 21 of set 10 | burnie
# Processing Record 22 of set 10 | boguchany
# Processing Record 23 of set 10 | doha
# Processing Record 24 of set 10 | kristiansund
# Processing Record 25 of set 10 | uttaradit
# Processing Record 26 of set 10 | acapulco
# Processing Record 27 of set 10 | te anau
# Processing Record 28 of set 10 | olinda
# Processing Record 29 of set 10 | maragogi
# Processing Record 30 of set 10 | truth or consequences
# Processing Record 31 of set 10 | san carlos
# Processing Record 32 of set 10 | eyl
# Processing Record 33 of set 10 | mecca
# Processing Record 34 of set 10 | westpunt
# City not found. Skipping | westpunt
# Processing Record 35 of set 10 | mayor pablo lagerenza
# Processing Record 36 of set 10 | hay river
# Processing Record 37 of set 10 | mokhotlong
# Processing Record 38 of set 10 | villiers
# Processing Record 39 of set 10 | sterling
# Processing Record 40 of set 10 | jiguani
# Processing Record 41 of set 10 | barbar
# City not found. Skipping | barbar
# Processing Record 42 of set 10 | kerman
# Processing Record 43 of set 10 | santa maria
# Processing Record 44 of set 10 | oussouye
# Processing Record 45 of set 10 | cidreira
# Processing Record 46 of set 10 | petropavlovsk-kamchatskiy
# Processing Record 47 of set 10 | baghdad
# Processing Record 48 of set 10 | gornopravdinsk
# Processing Record 49 of set 10 | shelburne
# Processing Record 50 of set 10 | porbandar
# Processing Record 0 of set 11 | araguatins
# City not found. Skipping | araguatins
# Processing Record 1 of set 11 | vila do maio
# Processing Record 2 of set 11 | zaysan
# Processing Record 3 of set 11 | kropotkin
# Processing Record 4 of set 11 | skibbereen
# Processing Record 5 of set 11 | oyama
# Processing Record 6 of set 11 | dhar
# Processing Record 7 of set 11 | mahibadhoo
# Processing Record 8 of set 11 | dingle
# Processing Record 9 of set 11 | yola
# Processing Record 10 of set 11 | tuni
# Processing Record 11 of set 11 | kwinana
# Processing Record 12 of set 11 | pyay
# Processing Record 13 of set 11 | bud
# Processing Record 14 of set 11 | derzhavinsk
# Processing Record 15 of set 11 | havoysund
# Processing Record 16 of set 11 | dhing
# Processing Record 17 of set 11 | leiyang
# Processing Record 18 of set 11 | nova olinda do norte
# Processing Record 19 of set 11 | x-can
# City not found. Skipping | x-can
# Processing Record 20 of set 11 | barawe
# City not found. Skipping | barawe
# Processing Record 21 of set 11 | bougouni
# Processing Record 22 of set 11 | namatanai
# Processing Record 23 of set 11 | aykhal
# Processing Record 24 of set 11 | hovd
# Processing Record 25 of set 11 | aborlan
# Processing Record 26 of set 11 | lakatoro
# Processing Record 27 of set 11 | muros
# Processing Record 28 of set 11 | mosquera
# Processing Record 29 of set 11 | tinglev
# Processing Record 30 of set 11 | huarmey
# Processing Record 31 of set 11 | nevelsk
# Processing Record 32 of set 11 | yirol
# City not found. Skipping | yirol
# Processing Record 33 of set 11 | shache
# Processing Record 34 of set 11 | mattru
# Processing Record 35 of set 11 | pokhara
# Processing Record 36 of set 11 | kilingi-nomme
# Processing Record 37 of set 11 | imbituba
# Processing Record 38 of set 11 | tinde
# Processing Record 39 of set 11 | barcelos
# Processing Record 40 of set 11 | labytnangi
# Processing Record 41 of set 11 | oum hadjer
# Processing Record 42 of set 11 | camacupa
# Processing Record 43 of set 11 | sungaipenuh
# Processing Record 44 of set 11 | magetan
# City not found. Skipping | magetan
# Processing Record 45 of set 11 | kargasok
# Processing Record 46 of set 11 | temir
# Processing Record 47 of set 11 | ayan
# Processing Record 48 of set 11 | tateyama
# Processing Record 49 of set 11 | arman
# Processing Record 50 of set 11 | gweru
# Processing Record 0 of set 12 | bur gabo
# City not found. Skipping | bur gabo
# Processing Record 1 of set 12 | verkhoyansk
# Processing Record 2 of set 12 | palmer
# Processing Record 3 of set 12 | smolensk
# Processing Record 4 of set 12 | barranca
# Processing Record 5 of set 12 | frutal
# Processing Record 6 of set 12 | lubango
# Processing Record 7 of set 12 | saleaula
# City not found. Skipping | saleaula
# Processing Record 8 of set 12 | bukene
# Processing Record 9 of set 12 | labuhan
# Processing Record 10 of set 12 | mountain home
# Processing Record 11 of set 12 | port augusta
# Processing Record 12 of set 12 | siwana
# Processing Record 13 of set 12 | cachira
# Processing Record 14 of set 12 | corn island
# Processing Record 15 of set 12 | bhatkal
# Processing Record 16 of set 12 | boa vista
# Processing Record 17 of set 12 | lasa
# Processing Record 18 of set 12 | ngukurr
# City not found. Skipping | ngukurr
# Processing Record 19 of set 12 | buribay
# Processing Record 20 of set 12 | marv dasht
# City not found. Skipping | marv dasht
# Processing Record 21 of set 12 | boende
# Processing Record 22 of set 12 | rodos
# Processing Record 23 of set 12 | tanout
# Processing Record 24 of set 12 | seoul
# Processing Record 25 of set 12 | honiara
# Processing Record 26 of set 12 | uray
# Processing Record 27 of set 12 | makakilo city
# Processing Record 28 of set 12 | mizque
# Processing Record 29 of set 12 | sinkat
# City not found. Skipping | sinkat
# Processing Record 30 of set 12 | yumen
# Processing Record 31 of set 12 | tiznit
# Processing Record 32 of set 12 | washim
# Processing Record 33 of set 12 | teguise
# Processing Record 34 of set 12 | shimoda
# Processing Record 35 of set 12 | moron
# Processing Record 36 of set 12 | kruisfontein
# Processing Record 37 of set 12 | kirakira
# Processing Record 38 of set 12 | vestmannaeyjar
# Processing Record 39 of set 12 | traverse city
# Processing Record 40 of set 12 | qaqortoq
# Processing Record 41 of set 12 | akyab
# Processing Record 42 of set 12 | west fargo
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Exporting data to a CSV
weather_df.to_csv("../output_data/Weather Data.csv")

# %%
# Displaying Data count
weather_df.count()
# Out:
# City                604
# Latitude            604
# Longitude           604
# Temperature (F)     604
# Humidity (%)        604
# Cloudiness (%)      604
# Wind Speed (mph)    604
# Country             604
# DateTime            604
# Datetime            559
# dtype: int64

# %%
# Converting strings to numeric floats and assigning to variables
latitude = pd.to_numeric(weather_df["Latitude"]).astype(float)
longitude = pd.to_numeric(weather_df['Longitude']).astype(float)
temperature = pd.to_numeric(weather_df["Temperature (F)"]).astype(float)
humidity = pd.to_numeric(weather_df['Humidity (%)']).astype(float)
wind_speed = pd.to_numeric(weather_df['Wind Speed (mph)']).astype(float)
cloudiness = pd.to_numeric(weather_df['Cloudiness (%)']).astype(float)

weather_df.head()
# Out:
#       City Latitude Longitude Temperature (F) Humidity (%) Cloudiness (%)  \
# 0   barrow    71.29   -156.79          -19.93           68              1
# 1     hilo    19.73   -155.09          71.924           88             90
# 2  ushuaia    -54.8     -68.3           55.67           50             40
# 3     teya    60.38     92.63           7.862           96             90
# 4  rikitea   -23.12   -134.97          79.376           80             93
#
#   Wind Speed (mph) Country DateTime            Datetime
# 0              2.6      US          2020-03-03 16:33:31
# 1              3.6      US          2020-03-03 16:33:23
# 2              8.7      AR          2020-03-03 16:33:32
# 3              2.1      RU          2020-03-03 16:33:32
# 4              7.2      PF          2020-03-03 16:33:33

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(latitude, temperature, facecolor = 'dodgerblue', edgecolors = 'black', alpha = 0.5)

plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature {today}')

plt.grid()

print('From this graph one may see that as you approach the equator, the maximum temperature drastically increases.')

plt.show()
# Out:
# From this graph one may see that as you approach the equator, the maximum temperature drastically increases.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(latitude, humidity, facecolor = 'dodgerblue', edgecolors = 'black', alpha = 0.5)

plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity {today}')

plt.grid()

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# The regression does not display a strong correlation between the data sets.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(latitude, cloudiness, facecolor = 'dodgerblue', edgecolors = 'black', alpha = 0.5)

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness {today}')

plt.grid()

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# The regression does not display a strong correlation between the data sets.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(latitude, wind_speed, facecolor = 'dodgerblue', edgecolors = 'black', alpha = 0.5)

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed {today}')

plt.grid()

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# The regression does not display a strong correlation between the data sets.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :].reset_index(drop = True)
southern_hemisphere_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :].reset_index(drop = True)

# %%
# Converting strings to numeric floats and assigning to variables northern hemisphere
northern_latitude = northern_hemisphere_df["Latitude"].astype(float)
northern_longitude = northern_hemisphere_df['Longitude'].astype(float)
northern_temperature = northern_hemisphere_df["Temperature (F)"].astype(float)
northern_humidity = northern_hemisphere_df['Humidity (%)'].astype(float)
northern_wind_speed = northern_hemisphere_df['Wind Speed (mph)'].astype(float)
northern_cloudiness = northern_hemisphere_df['Cloudiness (%)'].astype(float)

# Converting strings to numeric floats and assigning to variables southern hemisphere
southern_latitude = southern_hemisphere_df["Latitude"].astype(float)
southern_longitude = southern_hemisphere_df['Longitude'].astype(float)
southern_temperature = southern_hemisphere_df["Temperature (F)"].astype(float)
southern_humidity = southern_hemisphere_df['Humidity (%)'].astype(float)
southern_wind_speed = southern_hemisphere_df['Wind Speed (mph)'].astype(float)
southern_cloudiness = southern_hemisphere_df['Cloudiness (%)'].astype(float)

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression_plot(x_value_args, y_value_args):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value_args, y_value_args)
    regress_values = x_value_args * slope + intercept
    line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
    linear_regression_plot.line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
    print(f'Regression line equation is: {line_eq}')
    plt.scatter(x_value_args, y_value_args, facecolor = 'dodgerblue', edgecolors = 'black', alpha = 0.5)
    plt.plot(x_value_args, regress_values, 'r-')
    print(f'The r-squared is: {rvalue}')

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_latitude, northern_temperature)

plt.annotate(linear_regression_plot.line_eq,(10,-20),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f'Northern Latitude vs Temperature {today}')

print('The regression displays a negative correlation between latitude and temperature. \nAs you move away from the equator (Latitude = 0) the temperature decreases.')

plt.show()
# Out:
# Regression line equation is: y = -1.23x + 93.93
# The r-squared is: -0.9016179376513827
# The regression displays a negative correlation between latitude and temperature.
# As you move away from the equator (Latitude = 0) the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_latitude, southern_temperature)

plt.annotate(linear_regression_plot.line_eq,(-40,35),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title(f'Southern Latitude vs Temperature {today}')

print('The regression displays a positive correlation. \nAs you move closer to the equator (Latitude = 0) the temperature incraeses.')

plt.show()
# Out:
# Regression line equation is: y = 0.35x + 79.87
# The r-squared is: 0.44592624904026074
# The regression displays a positive correlation.
# As you move closer to the equator (Latitude = 0) the temperature incraeses.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_latitude, northern_humidity)

plt.annotate(linear_regression_plot.line_eq,(45,10),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Humitiy')
plt.title(f'Northern Latitude vs Humidity {today}')

print('The regression does not display any obvious correlations between the data sets.')

plt.show()
# Out:
# Regression line equation is: y = 0.23x + 63.35
# The r-squared is: 0.21387815469960952
# The regression does not display any obvious correlations between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_latitude, southern_humidity)

plt.annotate(linear_regression_plot.line_eq,(-55,27),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Humitiy')
plt.title(f'Southern Latitude vs Humidity {today}')

print('The correlation does not display any obvious correlations between the data sets.')

plt.show()
# Out:
# Regression line equation is: y = 0.44x + 86.59
# The r-squared is: 0.3431675355455762
# The correlation does not display any obvious correlations between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_latitude, northern_cloudiness)

plt.annotate(linear_regression_plot.line_eq,(42,10),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Northern Latitude vs Cloudiness {today}')

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# Regression line equation is: y = 0.5x + 28.91
# The r-squared is: 0.26037428151586056
# The regression does not display a strong correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_latitude, southern_cloudiness)

plt.annotate(linear_regression_plot.line_eq,(-55,60),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Southern Latitude vs Cloudiness {today}')

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# Regression line equation is: y = 1.3x + 79.13
# The r-squared is: 0.4510137408135088
# The regression does not display a strong correlation between the data sets.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression_plot(northern_latitude, northern_wind_speed)

plt.annotate(linear_regression_plot.line_eq,(5,12),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'Northern Latitude vs Wind Speed {today}')

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# Regression line equation is: y = 0.01x + 3.34
# The r-squared is: 0.09576703292173648
# The regression does not display a strong correlation between the data sets.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_regression_plot(southern_latitude, southern_wind_speed)

plt.annotate(linear_regression_plot.line_eq,(-40,10),fontsize = 15, color ='r')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title(f'Southern Latitude vs Wind Speed {today}')

print('The regression does not display a strong correlation between the data sets.')

plt.show()
# Out:
# Regression line equation is: y = -0.06x + 1.86
# The r-squared is: -0.359067989614092
# The regression does not display a strong correlation between the data sets.
